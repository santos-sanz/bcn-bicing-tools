# %%
import pandas as pd

stations_master_file = 'stations_master.csv'
stations_master = pd.read_csv(stations_master_file).sort_values(by='station_id')

# %%
stations_master
# Out:
#      station_id                                 name physical_configuration  \
# 0           1.0        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1           2.0                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2           3.0                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3           4.0                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4           5.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
# ..          ...                                  ...                    ...
# 505       516.0                    C/ SANT ADRIÀ, 88    ELECTRICBIKESTATION
# 506       517.0             AV. RASOS DE PEGUERA, 10    ELECTRICBIKESTATION
# 507       518.0                    C/ LLOBREGÓS, 115    ELECTRICBIKESTATION
# 508       519.0                       C/ PEDRELL, 52    ELECTRICBIKESTATION
# 509       521.0                                  BSM    ELECTRICBIKESTATION
#
# ...
